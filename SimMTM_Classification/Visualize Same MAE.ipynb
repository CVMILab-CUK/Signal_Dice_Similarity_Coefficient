# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # EEG Sleep -> FD-B

# %%
mse_loss_model_mae = np.array([7.2746, 7.0529, 6.9763, 6.9351, 6.9246 ])
mse_loss_model_f1  = np.array([65.5236, 66.8403, 68.0145, 67.8822,  68.5332])
mse_loss_model_acc = np.array([60.0929,60.9116, 62.2244, 62.6005, 62.7406 ])

hyb_loss_model_mae = np.array([7.2760, 7.0547, 6.9810, 6.9479, 6.9342])
hyb_loss_model_f1  = np.array([65.8953, 66.8515, 68.4824, 68.4824, 68.4824])
hyb_loss_model_acc = np.array([60.3806, 60.8599, 62.3055, 62.3055, 62.3055])

plt.figure()
plt.plot(mse_loss_model_mae, mse_loss_model_f1, "o-", label="MSE")
plt.plot(hyb_loss_model_mae, hyb_loss_model_f1,  "o-", label="SDSC")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
